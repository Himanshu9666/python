# %%
# introduction to pandas--->
# pandas is an open-source llibray of python which usused for handle data manipulations.

# %%
# !pip install pandas

# %%
import pandas as pd

# %%
# data structure of pands:
# (1) Series
# (2) Dataframe

# %%
# (1). series---> it is one dimenstional array and it returns only values not column name.

# %%
a=pd.Series([1,2,3,4,5])
a
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
type(a)
# Out:
# pandas.core.series.Series

# %%
# (2). Dataframe :: -> it is multi -dimensional array and it return values with column name.

# %%
# Task ::: we have to crete a datafrane of employees in which column are
# emp_id,emp_name,department,salary,working_hours

# %%
a = {
    "Emp_id": ['A101','A102','A103','A104','A105','A106'],
    "Emp_name": ['Sam', 'Rahul', 'Ankit', 'Alice', 'Saurav', 'Mohit'],
    "Department": ['IT', 'Operations', 'IT', 'IT', 'Operations', 'IT'],
    "Salary": [20000, 25000, 30000, 40000, 45000, 35000],
    "Working_hours": [8,9,8,9,8,9]
}

# %%
df=pd.DataFrame(a)
df
# Out:
#   Emp_id Emp_name  Department  Salary  Working_hours
# 0   A101      Sam          IT   20000              8
# 1   A102    Rahul  Operations   25000              9
# 2   A103    Ankit          IT   30000              8
# 3   A104    Alice          IT   40000              9
# 4   A105   Saurav  Operations   45000              8
# 5   A106    Mohit          IT   35000              9

# %%
# How can we export the dataframe into CSV data?

# %%
df.to_csv("emp_info.csv")  # to_csv mean export your data into csv file

# %%
df.to_csv("new_emp_info.csv",index=False) #indec=false means it will remove unname column.

# %%
# How to using csv data using pandas

# %%
df=pd.read_csv("/content/new_emp_info.csv")
df
# Out:
#   Emp_id Emp_name  Department  Salary  Working_hours
# 0   A101      Sam          IT   20000              8
# 1   A102    Rahul  Operations   25000              9
# 2   A103    Ankit          IT   30000              8
# 3   A104    Alice          IT   40000              9
# 4   A105   Saurav  Operations   45000              8
# 5   A106    Mohit          IT   35000              9

# %%
df =pd.read_csv("/content/new_emp_info.csv",encoding=1)
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-4255550016.py in <cell line: 0>()
# ----> 1 df =pd.read_csv("/content/new_emp_info.csv",encoding=1)
#       2 df
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
# shoees range 2000 to 5000
# massuri best palce to vist

# %%
df =pd.read_csv("/flipkart.himanshu.csv" )
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-2951269414.py in <cell line: 0>()
# ----> 1 df =pd.read_csv("/flipkart.himanshu.csv" )
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
# ...

# %%
df
# Out:
#   Emp_id Emp_name  Department  Salary  Working_hours
# 0   A101      Sam          IT   20000              8
# 1   A102    Rahul  Operations   25000              9
# 2   A103    Ankit          IT   30000              8
# 3   A104    Alice          IT   40000              9
# 4   A105   Saurav  Operations   45000              8
# 5   A106    Mohit          IT   35000              9

# %%
df['Company'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Company'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-2634053808.py in <cell line: 0>()
# ----> 1 df['Company'].value_counts()
#
# ...

# %%
df.describe()

# %%
df.head()
df.tail()
df[1:5]

# %%
df.loc[1:2,['Company','Type',"Discount",'price','off']]
df.iloc[1:2,[1,2,3,4]]

# %%
df['off'].value_counts()
df.isnull().sum()
df.dtypes
df['Company'].value_counts()

# %%
df['Company']=df['Company'].map({'Duke':'1','PUMA':'2','Cult':'3','ADIDAS':'4','New Balance':'5'})
df

# %%
df =pd.read_csv("/massuriii.csv" )

# %%
df

# %%
df=pd.read_csv("/covid_toy.csv")
df

# %%
df.head()

# %%
df.tail()

# %%
df.describe()

# %%
df.info()

# %%
df.isnull().sum()

# %%
df['fever'] = df['fever'].fillna(df['fever']).mean()

# %%
df.isnull().sum()

# %%
# loc() and iloc()
# df.loc[row_range,column_name]----> start value include and last value include.
# df.iloc[row_range,column_range]---> start value include but last value exclude

# %%
df.loc[5:10,['age','fever','cough']]

# %%
df.head(11)

# %%
df['gender'].value_count()

# %%
df.head(2)

# %%
df['gender'].value_counts()

# %%
df.head(2)

# %%
df['gender'] = df['gender'].map({'Male':1,'Female':0})
df['cough'] = df['cough'].map({"mild":0,"strong":1})

# %%
df['has_covid'] =df["has_covide"].map

# %%
df.drop(columns = ['city'])

# %%
df=df.drop(column =['city']) # how to drop or delet one or more columns

# %%
# df.head

# %%
df.sort_index() #sort the data

# %%
df=df.rename(columns = {'cough':"updated_cough"})

# %%
df['Age']=df[age].add(10)

# %%
# df.head(5)

# %%
df=df.drop(columns = ['Age'])

# %%
df.head(2)

# %%
df[["age","fever"]]  # using this method,we can filter the data

# %%
df=pd.read_csv("/content/flipkart.himanshu.csv")
df
