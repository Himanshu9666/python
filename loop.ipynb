# %%
'''loop'''
#..for loop
#..while
'''write 1 to 7 number in loop'''
# for i in range(1,8):
#     print(i,end=" ")

# a='python'
# for i in range(len(a)):
#     print(a[i],end=" ")

# a='python'
# for i in range(len(a)):
#   print(i)

#for i in range(3):
#   for j in range(5)
#       print(i,j)

'''pattern'''
# for i in range(1,6,1):
#     print(i*'*')

# for i in range(5,0,-1):
#     print(i*'*')


# for i in range(1,6,1):
#     print(i*'*')
# for i in range(5,0,-1):
#     print(i*'*')
'''for tringle'''
# for i in range(1,6):
#     for j in range(i):
#         print("*",end=' ')
#     print()

# for i in range(5,0,-1):
#     for j in range(i):
#         print("*",end=' ')
#     print()
'''for number'''

# for i in range(1,6):
#     for j in range(i):
#         print(i,end=' ')
#     print()


# for i in range(1,6):
#     for j in range(1,i+1):
#         print(j,end=" ")
#     print()


# for i in range(5,0,-1):
#     for j in range(1,i+1):
#         print(j,end=" ")
#     print()

# n = 5
# for i in range(1, n + 1):
#     for space in range(n - i):
#         print(" ", end="")
#     for j in range(1, i + 1):
#         print(j, end="")
#     print()

# n = 5
# for i in range(n, 0, -1):
#     for space in range(n - i):
#         print(" ", end="")
#     for j in range(1, i + 1):
#         print(j, end="")
#     print()

'''piramind'''
# n=5
# for i in range(1,n+1):
#     print(" "*(n-i) ,end="")
#     for j in range(1 ,i+1):
#         print(j , end=" ")
#     print()

'''Hollow square'''
# n=5
# for i in range(n):
#     for j in range(n):
#         if i==0 or i==n-1 or j==0 or j==n-1:
#             print(j+1,end=" ")
#         else:
#             print(" ",end=" ")
#     print()

# n=5
# for i in range(1,n+1):
#     for j in range(1,i+1):
#         if j==1 or j==i or i==n:
#          print("*",end=" ")
#         else:
#          print(" ",end="")
#     print()

# n=5
# for i in range(n,1,-1):
#     for j in range(i,1,-1):
#         if j==1 or j==i or i==n:
#          print("*",end=" ")
#         else:
#          print(" ",end="")
#     print()

'''1 to 10'''
# count=1
# for i in range(1,5):
#     for j in range(1,i+1):
#         print(count,end='')
#         count+=1
#     print(" ")

'''while loop'''
# i=1
# n=4
# while (i<=n):
#     print(i)
#     i=i+1

# i=int(input("Enter the largest number :"))
# n=int(input("Enter the smallest number :"))
# p=int(input("Enter the step number :"))
# while (i>=n):
#     print(i)
#     i=i-p

'''write a program sum of the given number'''
# i=1
# n=4
# sum=0
# while (i<=n):
#     sum=sum+i
#     i=i+1
#     print(i)
'''write a program print sum of square of given number'''
# i=1
# n=4
# sum=0
# while(i<=n):
#     sum=sum+(i**2)
#     i=i+1
#     print(sum)
'''secound'''
# i = 1
# n = 4
# square = 2

# while i <= n:
#     square = square * i
#     i = i + 1

'''write a program who print sum of cube of a given number and check number is armstrong or not '''
# i=int(input("Enter number :"))
# sum=0
# orignal=i
# while i>0:
#     sum=sum+(i%10)**3
#     i=i//10
# if(orignal==sum)
#     print("Number is armstrong")
# else:
#     print("Number is not armstrong")
'''odd number sum'''
# i=1234
# odd=0
# even=0
# while(i>0):
#     d=i%10
#     if(d%2==0):
#         even=even+d
#     else:
#         odd=odd+d
#     i=i//10
#     print("total even:",even,"total odd:",odd)
'''write a program who reverse a given number'''
# i=123
# rev=10
# while(i>0):
#     rev=(rev*10)+(i%10)
#     i=i//10
# print(rev)
'''write a prgram which is palindrom or not'''
#input=121---->palindrom
# num = int(input("Enter a number: "))
# original = num
# reversed_num = 0

# while num > 0:
#     digit = num % 10
#     reversed_num = reversed_num * 10 + digit
#     num = num // 10

# is_palindrome = (original == reversed_num)

'''write a prgram who print table of 5 using while loop'''
# num = 5
# i = 1
# while i<=10:
#     table=5*i
#     print(table)
#     i=i+1

# while i <= 10:
#     print(f"{num} x {i} = {num * i}")
#     i += 1


'''write a program find consonet '''
# n = 'Python program'
# count = 0
# vowels = 'aeiouAEIOU'
# i = 0

# while i < len(n):
#     char = n[i]
#     if char.isalpha() and char not in vowels:
#         count += 1
#     i += 1

# print("Number of consonants:", count)
'''print all divisors of 36 '''
# n=36
# i=1
# while i<=n:
#     if n%i==0:
#         print(i)
#     i=i+1

'''List in pyton'''
# a=['sam',45,56.08,'rahu']
# print[a]

# print(type(a))

#indexing
# print(a[0]) #forward indexing
# print(a[3])
# print(a[1])
# print(a[2])

#Reverse indexing
# # print(a[-1])
# print(a[-2])
# print(a[-3])

#slicing in list
# a=['sam',45,56.90,'rahul',[12,'raj',78.56]]
# a[0:2]
# a[1:4]
# a[2:]
# a[:]
# a[-1::-1]
# a[3][2]
# a[4][1][1]

#list is mutable data type
# a=['sam',45,56.90,'rahul']
# a[3]='python'
# print(a)

#loop in list
# a=['sam',45,56.90,'python']
# for i in a :
#     print(a[i],end=" ")

#properties of list
#(1) concateination
# a=[1,2,3]
# b=[4,5,6]
# c=a+b
# print(c)

#(2)replication
# a=[1,2,3]
# a*3
