# %%
# file =open("hell.txt",'r')
# for i in file:
#     print(i)

# file =open("hell.txt","r")
# print(file.readline())

#using the with statement
# with open("hell.txt") as file:
#     data = file.read()
# print(data)

# with open("hell.txt","r") as file:
#     data=file.readlines()
#     for line in data:
#         word=line.split()
#         print(word)

# file=open("super.txt",'w')
# file.write("this is the write command")
# file.write("it allow us to write in a particular file ")
# file.write("we have to read loop in python ")
# file.write("we love js ")
# file.write("we love maths,english")
# file.close()

# with open ("file.txt","w") as f:
#     f.write("hello world !!")

# %%
# ZEroDivisionError
a = 10
b = 4
# the 'try' always runs
try:
    c = a / b
# this block runs when any exception error occurs in the program
except ZeroDivisionError:
    print("Enter natural numbers..")
# this else block will run only when there is no exceptions in the program
else:
    print(c)
# Out:
# please enter the value gretar then 0

# %%
# name error
z = []
try:
  print(x)
except NameError:
  print("define var")

# %%
# type error
try:
  a = 'str'
  b = 10
  c = a + b
except TypeError:
  print("use similar data type to perform this operation")

# %%
# value error
try:
  a = 'budis'
  b = int(a)
except ValueError:
  print('use integer value')
else:
  print(b)
# Out:
# use integer value

# %%
# index error
li = [1, 2, 3, 4, 5, 6]
print(li[0])
print(li[6])

# %%
li = [1, 2, 3, 4, 5, 6]
try:
  element = li[8]
except IndexError:
  print('enter valid index')
else:
  print(element)

# %%
# key error
d = {
    "name": 'aman',
    "batch": 'A-18',
    "number": '654548675'
}

try:
  print(d['Aame'])
except KeyError:
  print('enter valid key')

# %%
file = open('abd.txt', 'r')
file.read()
file.close()

# %%
# file not found error
# try block also run always...
try:
  file = open('sample.txt','r')
  content = file.read()
# it only works when try block gives an error
except FileNotFoundError:
  print('The file do not exist')
# it will only run when try block do not gives error
else:
  print(content)
# this block always run
finally:
  file.close()
  print('This block will always run')

# %%
def age_validation(age):
  if age>=18:
    print("you are rlible for vote!")
  else:
    print("You are not eligible for vote")

age_validation(17)
# Out:
# You are not eligible for vote

# %%
def age_validation(age):
  if age<0:
    # raise keyword is used to throw the execption
    #Exception -> it's general purpose class
    raise Exception(" Please enter the age valid")
  else:
    print("age is validated")
  try:
    age_validation(-1)
  except Exception as e:
    print("you 've got this exception: ",e)

# %%
#Bank managment
#1. Bank ATM Withdrawal
# Scenario: A customer tries to withdraw money from an ATM.
# Question: What exception should be raised if the withdrawal amount is greater than the
# account balance?
balance =20000
def withdraw(money):
  global balance
  if money>balance:
    raise Exception("paisa itna hai hi nhi tumhare account me ")
  else:
    balance = balance - money
    print("paisa nikal gya")
    print("bacha hu balance ",balance)
try:
    withdraw(200000)
except Exception as e:
    print("kuch exception aaya hai :",e)
# Out:
# kuch exception aaya hai : paisa itna hai hi nhi tumhare account me

# %%
# 2. Voting Eligibility
# Scenario: A user is entering their age in a voting application.
# Question: What exception should be raised if the user enters a negative age or an age
# greater than 120?
def voting_age(age):
    if age < 0 or age > 120:
        raise ValueError(" Invalid age entered! Age must be between 0 and 120.")
    elif age < 18:
        print("You are not eligible to vote.")
    else:
        print("You are eligible to vote.")

try:
    age = int(input("Enter your age: "))
    voting_age(age)
except ValueError as e:
    print("Error:", e)
# Out:
# Enter your age: 121
# Error:  Invalid age entered! Age must be between 0 and 120.

# %%
# 4. Password Strength
# Scenario: A website requires users to create a password during registration.
# Question: What exception should be raised if the user enters a password shorter than 8
# characters?
def password(num):
  if len(num)<6:
    raise Exception ("plese enter the long password")
  else:
   print(" Password accepted.")
try:
    num = input("Enter your password: ")
    password(num)
except ValueError as e:
    print("Error:", e)
# Out:
# Enter your password: hsjfjdfdg
#  Password accepted.

# %%
# 3. Online Exam Marks
# Scenario: A teacher is entering marks for students in an online exam system.
# Question: What exception should be raised if any entered marks are less than 0 or
# greater than 100?
