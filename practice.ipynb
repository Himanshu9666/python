# %%
import numpy as np

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/placement - placement.csv')
df
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
df.head() #top 5 data
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1
# 4  7.52          7.30       1

# %%
df.tail() #bottom  5 data
# Out:
#     cgpa  resume_score  placed
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0

# %%
df.describe () # staties view
# Out:
#            cgpa  resume_score      placed
# count  100.0000    100.000000  100.000000
# mean     6.9422      6.930500    0.500000
# std      1.1192      0.979608    0.502519
# min      5.2700      4.950000    0.000000
# 25%      5.9800      6.190000    0.000000
# 50%      6.6200      7.055000    0.500000
# 75%      8.0450      7.640000    1.000000
# max      9.4000      9.060000    1.000000

# %%
top_left_corner_df =df.iloc[:4,:3] #iloc[row_range,column_range]
top_left_corner_df
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1

# %%
df.loc[1:3,['cgpa','placed']]
# Out:
#    cgpa  placed
# 1  6.17       0
# 2  8.27       1
# 3  6.88       1

# %%
s=df.axes
s
# Out:
# [RangeIndex(start=0, stop=100, step=1),
#  Index(['cgpa', 'resume_score', 'placed'], dtype='object')]

# %%
p=df.dtypes
p
# Out:
# cgpa            float64
# resume_score    float64
# placed            int64
# dtype: object

# %%
b=df.empty    # it returns true if there any missing data in dataframe otherwise false
b
# Out:
# False

# %%
df.isnull().sum # for check missing values.
# Out:
# <bound method DataFrame.sum of      cgpa  resume_score  placed
# 0   False         False   False
# 1   False         False   False
# 2   False         False   False
# 3   False         False   False
# 4   False         False   False
# ..    ...           ...     ...
# 95  False         False   False
# 96  False         False   False
# 97  False         False   False
# 98  False         False   False
# 99  False         False   False
#
# [100 rows x 3 columns]>

# %%
df.dropna() # for remove missing row

# %%
i=df.ndim # number of axes(it is 2)
i
# Out:
# 2

# %%
t=df.shape #shape =n(rows),n(columns)
t
df.shape[0] #total rows in data
df.shape[1] #total columns in data
# Out:
# 3

# %%
d= df.size    #row count * column count
d
# Out:
# 300

# %%
a=df.values   # get a numpy array for df
a
# Out:
# array([[8.14, 6.52, 1.  ],
#        [6.17, 5.17, 0.  ],
#        [8.27, 8.86, 1.  ],
#        [6.88, 7.27, 1.  ],
#        [7.52, 7.3 , 1.  ],
#        [8.77, 6.19, 1.  ],
#        [5.34, 7.09, 0.  ],
#        [6.56, 6.29, 0.  ],
#        [6.32, 6.71, 0.  ],
#        [7.69, 7.12, 1.  ],
#        [6.18, 6.35, 0.  ],
#        [5.44, 6.54, 0.  ],
#        [6.09, 7.01, 0.  ],
#        [8.5 , 5.09, 1.  ],
#        [7.51, 6.25, 1.  ],
#        [8.88, 5.93, 1.  ],
#        [8.04, 7.64, 1.  ],
#        [7.81, 8.71, 1.  ],
#        [5.94, 5.88, 0.  ],
#        [6.75, 8.11, 1.  ],
#        [5.8 , 8.06, 0.  ],
#        [6.53, 7.64, 0.  ],
#        [6.16, 5.77, 0.  ],
#        [6.05, 7.13, 0.  ],
#        [8.22, 6.18, 1.  ],
#        [7.76, 5.68, 1.  ],
#        [6.27, 6.47, 0.  ],
#        [5.51, 6.15, 0.  ],
#        [7.46, 7.67, 1.  ],
#        [6.19, 7.3 , 0.  ],
#        [7.36, 7.15, 1.  ],
#        [5.92, 7.02, 0.  ],
#        [5.87, 7.96, 0.  ],
#        [8.43, 7.73, 1.  ],
# ...

# %%
df=df.copy()

# %%
p=df.sort_values(by='resume_score')  #it short the value from spacif datafrsme
p
# Out:
#     cgpa  resume_score  placed
# 94  8.01          4.95       1
# 87  5.62          5.05       0
# 13  8.50          5.09       1
# 41  8.68          5.15       1
# 1   6.17          5.17       0
# ..   ...           ...     ...
# 17  7.81          8.71       1
# 38  6.00          8.72       0
# 65  6.04          8.75       0
# 2   8.27          8.86       1
# 69  8.06          9.06       1
#
# [100 rows x 3 columns]

# %%
r=df.sort_index()
r
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
df['cgpa']=df['cgpa'].astype(int)

# %%
df.dtypes
# Out:
# cgpa              int64
# resume_score    float64
# placed            int64
# dtype: object

# %%
df['cgpa'] =df['cgpa'].astype(str)

# %%
df.dtypes
# Out:
# cgpa             object
# resume_score    float64
# placed            int64
# dtype: object

# %%
df['resume_score'] =df['cgpa'].astype(int)

# %%
df.dtypes
# Out:
# cgpa            int64
# resume_score    int64
# placed          int64
# dtype: object

# %%
t =df.add(4)
t
# Out:
#     cgpa  resume_score  placed
# 0     20            12       5
# 1     18            10       4
# 2     20            12       5
# 3     18            10       5
# 4     19            11       5
# ..   ...           ...     ...
# 95    18            10       4
# 96    20            12       5
# 97    18            10       4
# 98    20            12       5
# 99    18            10       4
#
# [100 rows x 3 columns]

# %%
s=df.count()
s
# Out:
# cgpa            100
# resume_score    100
# placed          100
# dtype: int64

# %%
p=df.max()
p
# Out:
# cgpa            17
# resume_score     9
# placed           1
# dtype: int64

# %%
q=df.min()
q
# Out:
# cgpa            13
# resume_score     5
# placed           0
# dtype: int64

# %%
g=df.filter( items = ['cgpa','placed'])
g
df[['cgpa','placed']] # secound option of filtering
# Out:
#     cgpa  placed
# 0     16       1
# 1     14       0
# 2     16       1
# 3     14       1
# 4     15       1
# ..   ...     ...
# 95    14       0
# 96    16       1
# 97    14       0
# 98    16       1
# 99    14       0
#
# [100 rows x 2 columns]

# %%
s=df.filter(items =[5,6],axis =0) ## axis = 0 means row wise operation
s
# Out:
#    cgpa  resume_score  placed
# 5    16             8       1
# 6    13             5       0

# %%
t= df.filter(like='5',axis=0)
t
# Out:
#     cgpa  resume_score  placed
# 5     16             8       1
# 15    16             8       1
# 25    15             7       1
# 35    16             8       1
# 45    16             8       1
# 50    16             8       1
# 51    14             6       0
# 52    13             5       0
# 53    14             6       0
# 54    13             5       0
# 55    14             6       1
# 56    14             6       0
# 57    14             6       0
# 58    14             6       0
# 59    13             5       0
# 65    14             6       0
# 75    14             6       1
# 85    14             6       0
# 95    14             6       0

# %%
p=df.rename(columns={'cgpa':'updated_cgpa','resume_score' : 'semester_marks'}) # how to rename a column
p
# Out:
#     updated_cgpa  semester_marks  placed
# 0             16               8       1
# 1             14               6       0
# 2             16               8       1
# 3             14               6       1
# 4             15               7       1
# ..           ...             ...     ...
# 95            14               6       0
# 96            16               8       1
# 97            14               6       0
# 98            16               8       1
# 99            14               6       0
#
# [100 rows x 3 columns]

# %%
df['half']=df['cgpa'].where(df['cgpa']>7,other =0)
df.head(10)
# Out:
#    cgpa  resume_score  placed  half
# 0    16             8       1    16
# 1    14             6       0    14
# 2    16             8       1    16
# 3    14             6       1    14
# 4    15             7       1    15
# 5    16             8       1    16
# 6    13             5       0    13
# 7    14             6       0    14
# 8    14             6       0    14
# 9    15             7       1    15

# %%
df=pd.read.csv('')

# %%
df.groupby('has_covid').size()
